# %%
d ={"key":"value","k1":"v1"}

# %%
d["key"]
# Out:
# 'value'

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
# we can see , we are not be able to access it , in order to access we need config box:

# %%
from box import ConfigBox
# we required ConfigBox to run yaml file.

# %%
d2 = ConfigBox(d)

# %%
d2
# Out:
# ConfigBox({'key': 'value', 'k1': 'v1'})

# %%
d2.key
# Out:
# 'value'

# %%
def get_product(x:int,y:int)->int:
    return x*y

# %%
get_product(2,4)
# Out:
# 8

# %%
get_product(2,"4")
# Out:
# '44'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int,y:int)->int:
    return x*y

# %%
print(get_product(2,"4"))
# Out:
# 44

# %%
## End to #nd Machine Learning Project with _MLflow

# %%
## Workflows

# %% [markdown]
# 1. Update  config.yaml
# 2. udate schema.yaml
# 3. Update params.yaml
# 4.update the entity
# 5. update the configuration manager in src config
# 6.update teh componenets
# 7. update the components
# 8.update the pipeline
# 9. update the main.py
# 10.update the app.py
# 9.update the dvc.yaml
